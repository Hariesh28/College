# %%
import pandas as pd # type: ignore
import numpy as np  # type: ignore
from sklearn.impute import SimpleImputer #type: ignore
from sklearn.preprocessing import MinMaxScaler #type: ignore
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('iris.csv')
arr = [[1, 2], [np.nan, 3], [7, 6]]

# %%
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
imputer.fit_transform(arr)
# Out:
# array([[1., 2.],
#        [4., 3.],
#        [7., 6.]])

# %%
arr = [[-1, 2], [-0.5, 6], [0, 10], [1, 18]]

# %%
scaler = MinMaxScaler()
scaler.fit_transform(arr)
# Out:
# array([[0.  , 0.  ],
#        [0.25, 0.25],
#        [0.5 , 0.5 ],
#        [1.  , 1.  ]])

# %%
df.head()
# Out:
#    sepallength  sepalwidth  petallength  petalwidth        class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
df.tail()
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica

# %%
print(df['sepallength'].notnull().sum())
print(df['sepallength'].count())
# Out:
# 150
# 150

# %%
df['petalwidth'].dtype
# Out:
# dtype('float64')

# %%
df['petallength'].mean()
# Out:
# 3.758666666666666

# %%
df['petalwidth'].std()
# Out:
# 0.7631607417008414

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(df['sepalwidth'])
# Out:
# <Axes: xlabel='sepalwidth', ylabel='Count'>

# %%
plt.figure(figsize=(10, 10))

plt.subplot(1, 2, 1)
plt.hist(df['sepalwidth'])
plt.xlabel('sepalwidth')
plt.ylabel('count')

plt.subplot(1, 2, 2)
plt.hist(df['petalwidth'])
plt.xlabel('petalwidth')
plt.ylabel('count')

plt.show()

# %%
cols = ['sepalwidth', 'petalwidth', 'sepallength', 'petallength']

for i in cols:
    sns.histplot(df[i])
    plt.show()

# %%
df
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
x = ['petallength', 'sepallength']
y = ['sepalwidth', 'petalwidth']

for i in x:
    for j in y:
        sns.scatterplot(x=i, y =j, hue='class', data=df)
        plt.show()
